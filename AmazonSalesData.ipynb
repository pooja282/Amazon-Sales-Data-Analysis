\
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0       CustKey  Discount Amount  Invoice Number  \
# count  65282.000000  6.528200e+04     65280.000000    65282.000000
# mean   32640.500000  1.001770e+07      1855.574835   216223.662020
# std    18845.434474  7.176148e+03      9037.140888    94992.281866
# min        0.000000  1.000045e+07   -255820.800000   100012.000000
# 25%    16320.250000  1.001272e+07       246.037500   117931.000000
# 50%    32640.500000  1.001966e+07       441.760000   222869.500000
# 75%    48960.750000  1.002351e+07       999.760000   314318.750000
# max    65281.000000  1.002758e+07    343532.660000   332842.000000
#
#          Line Number    List Price   Order Number   Sales Amount  \
# count   65282.000000  65282.000000   65282.000000   65282.000000
# mean    23713.849790    514.693380  180583.064352    2852.038373
# std     32664.024053    449.189182   67593.871116   15164.342107
# min      1000.000000      0.000000  100838.000000     200.010000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65282 entries, 0 to 65281
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        65282 non-null  int64
#  1   CustKey                           65282 non-null  int64
#  2   DateKey                           65282 non-null  object
#  3   Discount Amount                   65280 non-null  float64
#  4   Invoice Date                      65282 non-null  object
#  5   Invoice Number                    65282 non-null  int64
#  6   Item Class                        56993 non-null  object
#  7   Item Number                       65241 non-null  object
#  8   Item                              65282 non-null  object
#  9   Line Number                       65282 non-null  int64
#  10  List Price                        65282 non-null  float64
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                            int64
# CustKey                               int64
# DateKey                              object
# Discount Amount                     float64
# Invoice Date                         object
# Invoice Number                        int64
# Item Class                           object
# Item Number                          object
# Item                                 object
# Line Number                           int64
# List Price                          float64
# Order Number                          int64
# Promised Delivery Date               object
# Sales Amount                        float64
# Sales Amount Based on List Price    float64
# Sales Cost Amount                   float64
# Sales Margin Amount                 float64
# Sales Price                         float64
# Sales Quantity                        int64
# Sales Rep                             int64
# U/M                                  object
# ...

# %%
df.shape
# Out:
# (65282, 23)

# %%
df['Item'].count()
# Out:
# 65282

# %%
df
# Out:
#        Unnamed: 0   CustKey     DateKey  Discount Amount Invoice Date  \
# 0               0  10000481  2017-04-30          -237.91   2017-04-30
# 1               1  10002220  2017-07-14           368.79   2017-07-14
# 2               2  10002220  2017-10-17           109.73   2017-10-17
# 3               3  10002489  2017-06-03          -211.75   2017-06-03
# 4               4  10004516  2017-05-27         96627.94   2017-05-27
# ...           ...       ...         ...              ...          ...
# 65277       65277  10017638  2018-03-21           505.78   2018-03-21
# 65278       65278  10017638  2018-03-21           410.75   2018-03-21
# 65279       65279  10017638  2018-03-21           876.16   2018-03-21
# 65280       65280  10017638  2018-03-21         24226.77   2018-03-21
# 65281       65281  10017638  2018-03-21         24479.26   2018-03-21
#
#        Invoice Number Item Class Item Number                             Item  \
# ...

# %%
max(df['Sales Amount'])
# Out:
# 555376.0

# %%
min(df['Discount Amount'])
# Out:
# -255820.8

# %%
df.plot.scatter(x='Sales Amount', y='Discount Amount')
# Out:
# <AxesSubplot:xlabel='Sales Amount', ylabel='Discount Amount'>

# %%
sns.relplot(x='Sales Price', y='Sales Amount', data=df )

# %%
sns.pairplot(df)
